# %% [markdown]
# # Optimization of a Univariate Function

# %%
p  = 1e4*[0.00065143; -0.02212952; 0.2778; -1.5251; 3.0888]
x  = linspace(6,11,101)
px = p[1]*x.^4 + p[2]*x.^3 + p[3]*x.^2 +p[4]*x + p[5];

# %%
using PyPlot
plot(x,px)
hold("on")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f4698830050>)
